# %% [markdown]
# <a href="https://colab.research.google.com/github/ppzovsky/estudo_py/blob/main/pandas/Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#o dataframe e um conjunto de series
np.random.seed(101)

# %%
df = pd.DataFrame(np.random.randn(5, 4), index = 'A B C D E'.split(), columns='W X Y Z'.split())
#o metodo ssplit separa uma cadeia de strings

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W'] #a indexacao do dataframes ao feitas como nos dicionarios
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df[['Z','W']]
# Out:
#           Z         W
# A  0.503826  2.706850
# B  0.605965  0.651118
# C -0.589001 -2.018168
# D  0.955057  0.188695
# E  0.683509  0.190794

# %%
df['nova'] = np.random.rand(5)*10 #criamos uma nova coluna

# %%
df
# Out:
#           W         X         Y         Z      nova
# A  2.706850  0.628133  0.907969  0.503826  7.348191
# B  0.651118 -0.319318 -0.848077  0.605965  5.419618
# C -2.018168  0.740122  0.528813 -0.589001  9.131536
# D  0.188695 -0.758872 -0.933237  0.955057  8.079202
# E  0.190794  1.978757  2.605967  0.683509  4.029978

# %%
df.drop('nova', axis=1) #drop remove uma coluna
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z      nova
# A  2.706850  0.628133  0.907969  0.503826  7.348191
# B  0.651118 -0.319318 -0.848077  0.605965  5.419618
# C -2.018168  0.740122  0.528813 -0.589001  9.131536
# D  0.188695 -0.758872 -0.933237  0.955057  8.079202
# E  0.190794  1.978757  2.605967  0.683509  4.029978

# %%
df.drop('nova', axis=1, inplace=True)
#emboora haja a remocao da coluna, ela so e feita no ato, o inplace é quem
#garante que esta remocao vai sser permanente no DataFrame

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['A', 'Y']
 #serve para localizar um elemento especifico, passando a linha e coluna dele
# Out:
# 0.9079694464765431

# %%
df.loc['B', 'W']
# Out:
# 0.6511179479432686

# %%
df.iloc[1:4, 2:]
# Out:
#           Y         Z
# B -0.848077  0.605965
# C  0.528813 -0.589001
# D -0.933237  0.955057

# %%
#loc encontra os elementos baseado no nome das linhas e colunass
#iloc encontra os elementos baseado no numero das linhas e colunas, no mesmo metodo do numpy

# %%
bol = df > 0

# %%
bol
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[bol]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']>0]['Y']
# Out:
# A    0.907969
# B   -0.848077
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %%
df[(df['W']>0) & (df['Y']>1)]
#para selecoe condicionais, devemos sssempre utilizar os simbolos (& e |)
#se usarmoss 'and' ou 'or' apresenta um erro
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   index         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826
# 1     B  0.651118 -0.319318 -0.848077  0.605965
# 2     C -2.018168  0.740122  0.528813 -0.589001
# 3     D  0.188695 -0.758872 -0.933237  0.955057
# 4     E  0.190794  1.978757  2.605967  0.683509

# %%
col = 'RJ AM SP PR SC'.split()

# %%
col
# Out:
# ['RJ', 'AM', 'SP', 'PR', 'SC']

# %%
df['Estado'] = col

# %%
df
# Out:
#   index         W         X         Y         Z Estado
# 0     A  2.706850  0.628133  0.907969  0.503826     RJ
# 1     B  0.651118 -0.319318 -0.848077  0.605965     AM
# 2     C -2.018168  0.740122  0.528813 -0.589001     SP
# 3     D  0.188695 -0.758872 -0.933237  0.955057     PR
# 4     E  0.190794  1.978757  2.605967  0.683509     SC

# %%
df.set_index('Estado', inplace=True)

# %%
df
# Out:
#        index         W         X         Y         Z
# Estado
# RJ         A  2.706850  0.628133  0.907969  0.503826
# AM         B  0.651118 -0.319318 -0.848077  0.605965
# SP         C -2.018168  0.740122  0.528813 -0.589001
# PR         D  0.188695 -0.758872 -0.933237  0.955057
# SC         E  0.190794  1.978757  2.605967  0.683509
